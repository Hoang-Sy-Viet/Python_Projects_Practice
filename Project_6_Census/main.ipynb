# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\hsvie\Desktop\Python_Projects_Practice\Project_6_Census\data\Census.csv")

# %%
data.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
# 2      88635    103                16265              8923
# 3      20126     28                16938              9826
# 4         83     10                46062             29517
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
# 2                6197           70703            41515         21019
# 3                3077           87532            35561         17488
# 4               13962          304979           109818         61334
#
# [5 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
#  15  Christians            640 non-null    int64
#  16  Sikhs                 640 non-null    int64
#  17  Buddhists             640 non-null    int64
#  18  Jains                 640 non-null    int64
#  19  Secondary_Education   640 non-null    int64
#  20  Higher_Education      640 non-null    int64
#  21  Graduate_Education    640 non-null    int64
#  22  Age_Group_0_29        640 non-null    int64
#  23  Age_Group_30_49       640 non-null    int64
#  24  Age_Group_50          640 non-null    int64
# dtypes: int64(23), object(2)
# memory usage: 125.1+ KB

# %%
data.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Population              0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# dtype: int64

# %% [markdown]
# # Q. 1) How will you hide the indexes of the dataframe.

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data.style.hide()

# %% [markdown]
# # Q. 2) How can we set the caption / heading on the dataframe.

# %%
data.style.set_caption('Census_2011')

# %% [markdown]
# # Q. 3) Show the records related with the districts - New Delhi , Lucknow , Jaipur.

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data[data['District_name'].isin(['New Delhi','Lucknow','Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 93                23934           76076            43913         21773
# 109              703673         4091148          1646480        884057
# 156              639260         2678289          1161686        685258
#
# [3 rows x 25 columns]

# %% [markdown]
# # Q. 4) Calculate state-wise :
#     A. Total number of population.
#     B. Total no. of the population with different religions.

# %%
data.groupby('State_name')['Population'].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# MIZORAM                          1097206
# NAGALAND                         1978502
# NCT OF DELHI                    16787941
# ORISSA                          41974218
# PONDICHERRY                      1247953
# PUNJAB                          27743338
# RAJASTHAN                       68548437
# SIKKIM                            610577
# TAMIL NADU                      72147030
# TRIPURA                          3673917
# UTTAR PRADESH                  199812341
# UTTARAKHAND                     10086292
# WEST BENGAL                     91276115
# Name: Population, dtype: int64

# %%
data.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
data.groupby('State_name')[['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains']].sum().sort_values(by= ['Hindus'],ascending=False)
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# UTTAR PRADESH                159312654  38483967      356448    643500
# MAHARASHTRA                   89703057  12971152     1080073    223247
# BIHAR                         86078686  17557809      129247     23779
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# MADHYA PRADESH                66007121   4774695      213282    151412
# WEST BENGAL                   64385546  24654825      658618     63523
# TAMIL NADU                    63188168   4229479     4418331     14601
# RAJASTHAN                     60657103   6215377       96430    872930
# GUJARAT                       53533988   5846761      316178     58246
# KARNATAKA                     51317472   7893065     1142647     28773
# ORISSA                        39300341    911670     1161708     21991
# CHHATTISGARH                  23819789    514998      490542     70036
# JHARKHAND                     22376051   4793994     1418608     71422
# HARYANA                       22171128   1781342       50353   1243752
# ASSAM                         19180759  10679345     1165867     20672
# KERALA                        18282492   8873472     6141269      3814
# NCT OF DELHI                  13712100   2158684      146093    570581
# PUNJAB                        10678138    535489      348230  16004754
# UTTARAKHAND                    8368636   1406825       37781    236340
# HIMACHAL PRADESH               6532765    149881       12646     79896
# JAMMU AND KASHMIR              3566674   8567485       35631    234848
# TRIPURA                        3063903    316042      159882      1070
# MANIPUR                        1181876    239836     1179043      1527
# PONDICHERRY                    1089409     75556       78550       297
# GOA                             963877    121564      366130      1473
# CHANDIGARH                      852574     51447        8720    138329
# ARUNACHAL PRADESH               401876     27045      418732      3287
# SIKKIM                          352662      9867       60522      1868
# MEGHALAYA                       342078    130399     2213027      3045
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# DAMAN AND DIU                   220150     19277        2820       172
# NAGALAND                        173054     48963     1739651      1890
# MIZORAM                          30136     14832      956331       286
# LAKSHADWEEP                       1788     62268         317         8
#
#                              Buddhists    Jains
# State_name
# UTTAR PRADESH                   206285   213267
# MAHARASHTRA                    6531200  1400349
# BIHAR                            25453    18914
# ANDHRA PRADESH                   36692    53849
# MADHYA PRADESH                  216052   567028
# WEST BENGAL                     282898    60141
# TAMIL NADU                       11186    89265
# RAJASTHAN                        12185   622023
# GUJARAT                          30483   579654
# KARNATAKA                        95710   440280
# ORISSA                           13852     9420
# CHHATTISGARH                     70467    61510
# JHARKHAND                         8956    14974
# HARYANA                           7514    52613
# ASSAM                            54993    25949
# KERALA                            4752     4489
# NCT OF DELHI                     18449   166231
# PUNJAB                           33237    45040
# UTTARAKHAND                      14926     9183
# HIMACHAL PRADESH                 78659     1805
# JAMMU AND KASHMIR               112584     2490
# TRIPURA                         125385      860
# MANIPUR                           7084     1692
# PONDICHERRY                        451     1400
# GOA                               1095     1109
# CHANDIGARH                        1160     1960
# ARUNACHAL PRADESH               162815      771
# SIKKIM                          167216      314
# MEGHALAYA                         9864      627
# DADRA AND NAGAR HAVELI             634     1186
# ANDAMAN AND NICOBAR ISLANDS        338       31
# DAMAN AND DIU                      217      287
# NAGALAND                          6759     2655
# MIZORAM                          93411      376
# LAKSHADWEEP                         10       11

# %% [markdown]
# # Q. 5) How many Male Workers were there in Maharashtra state ?

# %%
data[data['State_name']== "MAHARASHTRA"]['Male_Workers'].sum()
# Out:
# np.int64(32616875)

# %% [markdown]
# # Q. 6) How to set a column as index of the dataframe ?

# %%
data = data.set_index('District_code')

# %%
data.head(3)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
# 3                           20869  ...         658   1092      88635    103
#
#                Secondary_Education  Higher_Education  Graduate_Education  \
# District_code
# 1                            74948             39709               21751
# 2                            66459             41367               27950
# 3                            16265              8923                6197
#
#                Age_Group_0_29  Age_Group_30_49  Age_Group_50
# District_code
# 1                      600759           178435         89679
# 2                      503223           160933         88978
# 3                       70703            41515         21019
#
# [3 rows x 24 columns]

# %% [markdown]
# # Q. 7a) Add a Suffix to the column names.

# %%
data = data.add_suffix('right_stone')
# Out:
#                      State_nameright_stone   District_nameright_stone  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Populationright_stone  Maleright_stone  Femaleright_stone  \
# District_code
# 1                             870354           474190             396164
# 2                             753745           398041             355704
# 3                             133487            78971              54516
# 4                             140802            77785              63017
# 5                             476835           251899             224936
# ...                              ...              ...                ...
# 636                            41816            19143              22673
# 637                           200222            97809             102413
# 638                            36842            20727              16115
# 639                           105597            54861              50736
# 640                           238142           127283             110859
#
#                Literateright_stone  Workersright_stone  \
# District_code
# 1                           439654              229064
# 2                           335649              214866
# 3                            93770               75079
# 4                            86236               51873
# 5                           261724              161393
# ...                            ...                 ...
# 636                          36470               11802
# 637                         154916               68301
# 638                          25332               17125
# 639                          78683               38579
# 640                         190266               96831
#
#                Male_Workersright_stone  Female_Workersright_stone  \
# District_code
# 1                               190899                      38165
# 2                               162578                      52288
# 3                                53265                      21814
# 4                                39839                      12034
# 5                               117677                      43716
# ...                                ...                        ...
# 636                               9093                       2709
# 637                              53139                      15162
# 638                              12714                       4411
# 639                              30612                       7967
# 640                              77563                      19268
#
#                Cultivator_Workersright_stone  ...  Christiansright_stone  \
# District_code                                 ...
# 1                                      34680  ...                   1700
# 2                                      55299  ...                   1489
# 3                                      20869  ...                    658
# 4                                       8266  ...                    604
# 5                                      54264  ...                    958
# ...                                      ...  ...                    ...
# 636                                       43  ...                    958
# 637                                     2372  ...                  18391
# 638                                      322  ...                  26077
# 639                                    10727  ...                  21870
# 640                                     5518  ...                  33037
#
#                Sikhsright_stone  Buddhistsright_stone  Jainsright_stone  \
# District_code
# 1                          5600                    66                39
# 2                          5559                    47                 6
# 3                          1092                 88635               103
# 4                          1171                 20126                28
# 5                         11188                    83                10
# ...                         ...                   ...               ...
# 636                           3                    21                14
# 637                          46                    63                54
# 638                         343                   119                 0
# 639                          77                    84                 4
# 640                         866                   135                27
#
#                Secondary_Educationright_stone  Higher_Educationright_stone  \
# District_code
# 1                                       74948                        39709
# 2                                       66459                        41367
# 3                                       16265                         8923
# 4                                       16938                         9826
# 5                                       46062                        29517
# ...                                       ...                          ...
# 636                                      8773                         5711
# 637                                     29456                        15930
# 638                                      6325                         3668
# 639                                     12707                        10042
# 640                                     42150                        29910
#
#                Graduate_Educationright_stone  Age_Group_0_29right_stone  \
# District_code
# 1                                      21751                     600759
# 2                                      27950                     503223
# 3                                       6197                      70703
# 4                                       3077                      87532
# 5                                      13962                     304979
# ...                                      ...                        ...
# 636                                     4475                      19760
# 637                                    18998                     102333
# 638                                     1300                      18786
# 639                                     5133                      57350
# 640                                    22388                     128402
#
#                Age_Group_30_49right_stone  Age_Group_50right_stone
# District_code
# 1                                  178435                    89679
# 2                                  160933                    88978
# 3                                   41515                    21019
# 4                                   35561                    17488
# 5                                  109818                    61334
# ...                                   ...                      ...
# 636                                 12543                     9428
# 637                                 60089                    37434
# 638                                 12088                     5922
# 639                                 30741                    17464
# 640                                 76332                    33128
#
# [640 rows x 24 columns]

# %% [markdown]
# # Q. 7b) Add a Prefix to the column names.

# %%
data = data.add_prefix("left_stone_")

# %%
data
# Out:
#               left_stone_left_stoneState_name  \
# District_code
# 1                           JAMMU AND KASHMIR
# 2                           JAMMU AND KASHMIR
# 3                           JAMMU AND KASHMIR
# 4                           JAMMU AND KASHMIR
# 5                           JAMMU AND KASHMIR
# ...                                       ...
# 636                               PONDICHERRY
# 637                               PONDICHERRY
# 638               ANDAMAN AND NICOBAR ISLANDS
# 639               ANDAMAN AND NICOBAR ISLANDS
# 640               ANDAMAN AND NICOBAR ISLANDS
#
#               left_stone_left_stoneDistrict_name  \
# District_code
# 1                                        Kupwara
# 2                                         Badgam
# 3                                    Leh(Ladakh)
# 4                                         Kargil
# 5                                          Punch
# ...                                          ...
# 636                                         Mahe
# 637                                     Karaikal
# 638                                     Nicobars
# 639                    North  AND Middle Andaman
# 640                                South Andaman
#
#                left_stone_left_stonePopulation  left_stone_left_stoneMale  \
# District_code
# 1                                       870354                     474190
# 2                                       753745                     398041
# 3                                       133487                      78971
# 4                                       140802                      77785
# 5                                       476835                     251899
# ...                                        ...                        ...
# 636                                      41816                      19143
# 637                                     200222                      97809
# 638                                      36842                      20727
# 639                                     105597                      54861
# 640                                     238142                     127283
#
#                left_stone_left_stoneFemale  left_stone_left_stoneLiterate  \
# District_code
# 1                                   396164                         439654
# 2                                   355704                         335649
# 3                                    54516                          93770
# 4                                    63017                          86236
# 5                                   224936                         261724
# ...                                    ...                            ...
# 636                                  22673                          36470
# 637                                 102413                         154916
# 638                                  16115                          25332
# 639                                  50736                          78683
# 640                                 110859                         190266
#
#                left_stone_left_stoneWorkers  \
# District_code
# 1                                    229064
# 2                                    214866
# 3                                     75079
# 4                                     51873
# 5                                    161393
# ...                                     ...
# 636                                   11802
# 637                                   68301
# 638                                   17125
# 639                                   38579
# 640                                   96831
#
#                left_stone_left_stoneMale_Workers  \
# District_code
# 1                                         190899
# 2                                         162578
# 3                                          53265
# 4                                          39839
# 5                                         117677
# ...                                          ...
# 636                                         9093
# 637                                        53139
# 638                                        12714
# 639                                        30612
# 640                                        77563
#
#                left_stone_left_stoneFemale_Workers  \
# District_code
# 1                                            38165
# 2                                            52288
# 3                                            21814
# 4                                            12034
# 5                                            43716
# ...                                            ...
# 636                                           2709
# 637                                          15162
# 638                                           4411
# 639                                           7967
# 640                                          19268
#
#                left_stone_left_stoneCultivator_Workers  ...  \
# District_code                                           ...
# 1                                                34680  ...
# 2                                                55299  ...
# 3                                                20869  ...
# 4                                                 8266  ...
# 5                                                54264  ...
# ...                                                ...  ...
# 636                                                 43  ...
# 637                                               2372  ...
# 638                                                322  ...
# 639                                              10727  ...
# 640                                               5518  ...
#
#                left_stone_left_stoneChristians  left_stone_left_stoneSikhs  \
# District_code
# 1                                         1700                        5600
# 2                                         1489                        5559
# 3                                          658                        1092
# 4                                          604                        1171
# 5                                          958                       11188
# ...                                        ...                         ...
# 636                                        958                           3
# 637                                      18391                          46
# 638                                      26077                         343
# 639                                      21870                          77
# 640                                      33037                         866
#
#                left_stone_left_stoneBuddhists  left_stone_left_stoneJains  \
# District_code
# 1                                          66                          39
# 2                                          47                           6
# 3                                       88635                         103
# 4                                       20126                          28
# 5                                          83                          10
# ...                                       ...                         ...
# 636                                        21                          14
# 637                                        63                          54
# 638                                       119                           0
# 639                                        84                           4
# 640                                       135                          27
#
#                left_stone_left_stoneSecondary_Education  \
# District_code
# 1                                                 74948
# 2                                                 66459
# 3                                                 16265
# 4                                                 16938
# 5                                                 46062
# ...                                                 ...
# 636                                                8773
# 637                                               29456
# 638                                                6325
# 639                                               12707
# 640                                               42150
#
#                left_stone_left_stoneHigher_Education  \
# District_code
# 1                                              39709
# 2                                              41367
# 3                                               8923
# 4                                               9826
# 5                                              29517
# ...                                              ...
# 636                                             5711
# 637                                            15930
# 638                                             3668
# 639                                            10042
# 640                                            29910
#
#                left_stone_left_stoneGraduate_Education  \
# District_code
# 1                                                21751
# 2                                                27950
# 3                                                 6197
# 4                                                 3077
# 5                                                13962
# ...                                                ...
# 636                                               4475
# 637                                              18998
# 638                                               1300
# 639                                               5133
# 640                                              22388
#
#                left_stone_left_stoneAge_Group_0_29  \
# District_code
# 1                                           600759
# 2                                           503223
# 3                                            70703
# 4                                            87532
# 5                                           304979
# ...                                            ...
# 636                                          19760
# 637                                         102333
# 638                                          18786
# 639                                          57350
# 640                                         128402
#
#                left_stone_left_stoneAge_Group_30_49  \
# District_code
# 1                                            178435
# 2                                            160933
# 3                                             41515
# 4                                             35561
# 5                                            109818
# ...                                             ...
# 636                                           12543
# 637                                           60089
# 638                                           12088
# 639                                           30741
# 640                                           76332
#
#                left_stone_left_stoneAge_Group_50
# District_code
# 1                                          89679
# 2                                          88978
# 3                                          21019
# 4                                          17488
# 5                                          61334
# ...                                          ...
# 636                                         9428
# 637                                        37434
# 638                                         5922
# 639                                        17464
# 640                                        33128
#
# [640 rows x 24 columns]
