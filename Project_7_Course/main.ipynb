# %%
import pandas as pd

# %%
df_course = pd.read_csv(r"C:\Users\hsvie\Desktop\Python_Projects_Practice\Project_7_Course\data\Udemy_Course.csv")

# %%
df_course.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
df_course.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
df_course.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# # Q. 1) What are all different subjects for which Udemy is offering courses ?

# %%
df_course.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 2        1.5 hours  2017-04-26T18:34:57Z  Musical Instruments

# %%
df_course['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %% [markdown]
# # Q. 2) Which subject has the maximum number of courses.

# %%
df_course['subject'].value_counts().max()
# Out:
# np.int64(1200)

# %% [markdown]
# # Q. 3) Show all the courses which are Free of Cost.

# %%
df_course['price'].value_counts()
# Out:
# price
# 20      830
# 50      468
# Free    310
# 200     295
# 40      217
# 30      170
# 25      154
# 95      152
# 100     133
# 195     127
# 35      116
# 150      88
# 45       83
# 75       81
# 60       75
# 120      37
# 55       35
# 85       31
# 65       30
# 125      30
# 80       29
# 145      27
# 70       26
# 90       19
# 180      17
# 115      16
# 175      13
# 105      11
# 190      10
# 140      10
# 135       8
# 110       8
# 185       6
# 165       6
# 170       5
# 160       4
# 130       3
# 155       2
# Name: count, dtype: int64

# %%
df_course[df_course['price'] == 'Free']
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %% [markdown]
# # Q. 4) Show all the courses which are Paid.

# %%
df_course.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 2        1.5 hours  2017-04-26T18:34:57Z  Musical Instruments

# %%
df_course[df_course['is_paid'] == True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# # Q. 5) Which are Top Selling Courses ?

# %%
df_course.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 2        1.5 hours  2017-04-26T18:34:57Z  Musical Instruments

# %%
df_course[df_course['num_subscribers'] == max(df_course['num_subscribers'])]
# Out:
#       course_id                          course_title  is_paid price  \
# 2230      41295  Learn HTML5 Programming From Scratch    False  Free
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 2230           268923         8629            45  All Levels       10.5 hours
#
#        published_timestamp          subject
# 2230  2013-02-14T07:03:41Z  Web Development

# %%
Course_is_paid = df_course[(df_course['is_paid']== True)]
Course_is_paid[Course_is_paid['num_subscribers']== max(Course_is_paid['num_subscribers'])]
# Out:
#       course_id                course_title  is_paid price  num_subscribers  \
# 3385     625204  The Web Developer Bootcamp     True   200           121584
#
#       num_reviews  num_lectures       level content_duration  \
# 3385        27445           342  All Levels         43 hours
#
#        published_timestamp          subject
# 3385  2015-11-02T21:13:27Z  Web Development

# %%
# cach 2:
df_course[(df_course['is_paid']== True)].sort_values(by=['num_subscribers'],ascending=False).head(1)
# Out:
#       course_id                course_title  is_paid price  num_subscribers  \
# 3385     625204  The Web Developer Bootcamp     True   200           121584
#
#       num_reviews  num_lectures       level content_duration  \
# 3385        27445           342  All Levels         43 hours
#
#        published_timestamp          subject
# 3385  2015-11-02T21:13:27Z  Web Development

# %% [markdown]
# # Q. 6) Which are Least Selling Courses ?

# %%
# cach 1:
df_course.sort_values(by=['num_subscribers'],ascending=True)
# Out:
#       course_id                                       course_title  is_paid  \
# 98      1219820  Accounting - The 6 most important rules you mu...     True
# 2350     371900  Learn to create Text fire effect in Adobe Phot...     True
# 3221    1057040                           Teeter-Totter Accounting     True
# 649     1233314                      Building a Balanced Scorecard     True
# 954     1169196  Credit concepts and checklist for bankers, cre...     True
# ...         ...                                                ...      ...
# 3316     764164              The Complete Web Developer Course 2.0     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3385     625204                         The Web Developer Bootcamp     True
# 776       59014                     Coding for Entrepreneurs Basic    False
# 2230      41295               Learn HTML5 Programming From Scratch    False
#
# ...

# %%
# cach 2:
df_course[df_course['num_subscribers'] == min(df_course['num_subscribers'])]
# Out:
#       course_id                                       course_title  is_paid  \
# 37      1234656                              4 Week Rhythm Mastery     True
# 44      1231958        60 Minutes to Fundamental Accounting Skills     True
# 91      1265814  ABRSM Grade III Piano Class - Handel Sonatina ...     True
# 98      1219820  Accounting - The 6 most important rules you mu...     True
# 185      872262                Adobe Photoshop pentru Social Media     True
# ...         ...                                                ...      ...
# 3467    1214670                  Tune that Sour Note on Your Piano     True
# 3512    1251654   Understand Core Finance Principles in 60 Minutes     True
# 3515    1035638                 Understanding Financial Statements     True
# 3516    1035638                 Understanding Financial Statements     True
# 3645    1271430        Workshop on Banking Credit Analysis Process     True
#
# ...

# %% [markdown]
# # Q. 7) Show all courses of Graphic Design where the price is below 100 ?

# %%
df_course.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 2        1.5 hours  2017-04-26T18:34:57Z  Musical Instruments

# %%
df_course.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
df_course['price'] =df_course['price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df_course['price'] =df_course['price'].astype(int)
#
# File c:\Users\hsvie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\hsvie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df_course['price'] = df_course['price'].

# %%
df_course['price']
# Out:
# 0         35
# 1         75
# 2         75
# 3         75
# 4         75
#         ...
# 3677     120
# 3678      70
# 3679      40
# 3680    Free
# 3681      50
# Name: price, Length: 3682, dtype: string

# %%
df_course[(df_course['subject']== 'Graphic Design') & (df_course['price'] < 100)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df_course[(df_course['subject']== 'Graphic Design') & (df_course['price'] < 100)]
#
# File c:\Users\hsvie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\hsvie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File c:\Users\hsvie\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
# ...
